# %% [markdown]
# # Aula prática de análise de dados com pandas

# %% [markdown]
# ###Importando bibliotecas

# %%
import pandas as pd
from google.colab import drive
from pandas_profiling import ProfileReport

# %% [markdown]
# ### Importando arquivo

# %%
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/ca-2021-01.csv', sep = ';', encoding= 'ISO-8859-1')
#
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataframe - Preço de combustível no Brasil em 2021

# %% [markdown]
# ###Link: https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis

# %%
df.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla     Municipio  \
# 0                 S             RS  SAO LEOPOLDO
# 1                 S             RS  SAO LEOPOLDO
# 2                 S             RS  SAO LEOPOLDO
# 3                 S             RS  SAO LEOPOLDO
# 4                 S             RS  SAO LEOPOLDO
#
#                                  Revenda      CNPJ da Revenda  \
# 0  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 3  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 4  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
#
#         Nome da Rua Numero Rua Complemento    Bairro        Cep  \
# 0  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 1  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 2  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# ...

# %%
df.columns.values
# Out:
# array(['ï»¿Regiao - Sigla', 'Estado - Sigla', 'Municipio', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Numero Rua', 'Complemento',
#        'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda',
#        'Valor de Compra', 'Unidade de Medida', 'Bandeira'], dtype=object)

# %%
dfColunas = ['Estado - Sigla', 'Municipio', 'Revenda',
       'Produto', 'Data da Coleta', 'Valor de Venda']

# %%
dfFiltrado =df.filter(items=dfColunas)
dfFiltrado = dfFiltrado.rename(columns = {'Estado - Sigla': 'Estado'})

# %%
dfFiltrado
# Out:
#        Estado     Municipio                                Revenda  \
# 0          RS  SAO LEOPOLDO  POSTOS DE COMBUSTIVEIS REDESINOS LTDA
# 1          RS  SAO LEOPOLDO  POSTOS DE COMBUSTIVEIS REDESINOS LTDA
# 2          RS  SAO LEOPOLDO  POSTOS DE COMBUSTIVEIS REDESINOS LTDA
# 3          RS  SAO LEOPOLDO  POSTOS DE COMBUSTIVEIS REDESINOS LTDA
# 4          RS  SAO LEOPOLDO  POSTOS DE COMBUSTIVEIS REDESINOS LTDA
# ...       ...           ...                                    ...
# 334676     ES       ARACRUZ       POSTO DE COMBUSTIVEL SHOW EIRELI
# 334677     ES       ARACRUZ       POSTO DE COMBUSTIVEL SHOW EIRELI
# 334678     ES       ARACRUZ       POSTO DE COMBUSTIVEL SHOW EIRELI
# 334679     ES       ARACRUZ       POSTO DE COMBUSTIVEL SHOW EIRELI
# 334680     ES       ARACRUZ       POSTO DE COMBUSTIVEL SHOW EIRELI
#
#                    Produto Data da Coleta Valor de Venda
# 0                 GASOLINA     01/01/2021          4,599
# ...

# %% [markdown]
# ### Quantidade de entradas por estado

# %%
colunaEstados = dfFiltrado['Estado']
colunaEstados = colunaEstados.value_counts()
colunaEstados
# Out:
# SP    111520
# RJ     25186
# MG     23190
# PR     20147
# RS     19334
# BA     15964
# SC     14449
# CE     14377
# MT     10728
# PE      9757
# GO      8021
# ES      6974
# MA      5429
# AM      5332
# MS      5148
# DF      4964
# PI      4233
# RN      4111
# PA      4007
# AL      3950
# PB      3759
# AC      3422
# RO      3375
# SE      3221
# TO      1946
# RR      1158
# AP       979
# Name: Estado, dtype: int64

# %% [markdown]
# ###Percentual por Estado

# %%
pEstados = [100*sigla/colunaEstados.sum() for sigla in colunaEstados]
pEstados
# Out:
# [33.32128205664498,
#  7.525374909241934,
#  6.928986109160664,
#  6.019762101822332,
#  5.776844218823298,
#  4.769915232714137,
#  4.3172453769410275,
#  4.295732354092404,
#  3.2054404044448295,
#  2.9153133879724273,
#  2.396610503733406,
#  2.0837752964763463,
#  1.6221416811829772,
#  1.5931588587341379,
#  1.5381811336765456,
#  1.4832034086189536,
#  1.2647864683086283,
#  1.2283338462595725,
#  1.1972594799226726,
#  1.1802283368341795,
#  1.1231590678885266,
#  1.0224661692776107,
#  1.008422946029204,
#  0.9624089804918714,
#  0.5814492008808387,
#  0.34600111748202017,
#  0.2925173523444713]

# %% [markdown]
# ### Filtrando somente por gasolina

# %%
dfColunas = ['Estado', 'Produto', 'Valor de Venda']
dfGasolina= dfFiltrado.filter(items=dfColunas)
dfGasolina = dfGasolina.loc[dfGasolina['Produto'] == 'GASOLINA']
dfGasolina
# Out:
#        Estado   Produto Valor de Venda
# 0          RS  GASOLINA          4,599
# 5          RS  GASOLINA          4,459
# 9          RS  GASOLINA          4,539
# 12         RS  GASOLINA          4,599
# 15         RS  GASOLINA          4,599
# ...       ...       ...            ...
# 334661     AL  GASOLINA          5,899
# 334663     RN  GASOLINA           5,98
# 334672     SC  GASOLINA          5,459
# 334673     PE  GASOLINA           5,59
# 334676     ES  GASOLINA           5,67
#
# [85260 rows x 3 columns]

# %% [markdown]
# ### Agrupando por preço de gasolina por estado

# %%
dfGasolina['Valor de Venda'] = dfGasolina['Valor de Venda'].str.replace(',','.')
dfGasolina = dfGasolina.astype({'Valor de Venda': 'float32'})
dfGasolina = dfGasolina.groupby('Estado').mean()
dfGasolina = dfGasolina.sort_values(by='Valor de Venda', ascending=False)
dfGasolina
# Out:
# <ipython-input-38-692939efed48>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGasolina = dfGasolina.groupby('Estado').mean()
#         Valor de Venda
# Estado
# AC            6.074777
# RJ            5.886587
# TO            5.684361
# GO            5.660654
# MG            5.658685
# RN            5.604649
# PI            5.574922
# PA            5.543767
# RS            5.531554
# BA            5.505574
# AL            5.487395
# RO            5.479875
# ES            5.446682
# DF            5.442646
# MS            5.422315
# CE            5.400451
# MT            5.371931
# SE            5.366111
# PE            5.304948
# AM            5.166393
# PB            5.156121
# SC            5.154913
# PR            5.151673
# MA            5.129764
# SP            5.119747
# ...

# %% [markdown]
# ### Dois tipos de gasolina - regex

# %%
dfColunas = ['Estado', 'Produto', 'Valor de Venda']
dfGasolina2= dfFiltrado.filter(items=dfColunas)
regex = '^GASOLINA'
dfGasolina2 = dfGasolina2.loc[dfGasolina2['Produto'].str.contains(regex, regex = True)]
dfGasolina2
# Out:
#        Estado             Produto Valor de Venda
# 0          RS            GASOLINA          4,599
# 2          RS  GASOLINA ADITIVADA          4,799
# 5          RS            GASOLINA          4,459
# 7          RS  GASOLINA ADITIVADA          4,499
# 9          RS            GASOLINA          4,539
# ...       ...                 ...            ...
# 334671     SC  GASOLINA ADITIVADA          5,559
# 334672     SC            GASOLINA          5,459
# 334673     PE            GASOLINA           5,59
# 334676     ES            GASOLINA           5,67
# 334679     ES  GASOLINA ADITIVADA           5,67
#
# [148450 rows x 3 columns]

# %% [markdown]
# ### Agrupando por tipo de gasolina no Brasil inteiro

# %%
dfGasolina2['Valor de Venda'] = dfGasolina2['Valor de Venda'].str.replace(',','.')
dfGasolina2 = dfGasolina2.astype({'Valor de Venda': 'float32'})
dfGasolina2 = dfGasolina2.groupby('Produto').mean()
dfGasolina2
# Out:
# <ipython-input-40-3c8d67a3f5e1>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGasolina2 = dfGasolina2.groupby('Produto').mean()
#                     Valor de Venda
# Produto
# GASOLINA                  5.346718
# GASOLINA ADITIVADA        5.495662

# %% [markdown]
# ### Pandas profiling

# %%
pip install https://github.com/ydataai/pandas-profiling/archive/master.zip
# Out:
# ...
#   Using cached https://github.com/ydataai/pandas-profiling/archive/master.zip
#   Preparing metadata (setup.py) ... done
# ...

# %%
profile = ProfileReport(dfFiltrado)
profile.to_notebook_iframe()
profile.to_file('saída.html')
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-05 18:28:22.514720&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
